# %%
#import needed python libraries
import numpy as np
import pandas as pd

#import raw data
gvData = pd.read_csv("stage3.csv")

# %%
for c in gvData.columns:
    print(c)
# Out:
# incident_id
# date
# state
# city_or_county
# address
# n_killed
# n_injured
# incident_url
# source_url
# incident_url_fields_missing
# congressional_district
# gun_stolen
# gun_type
# incident_characteristics
# latitude
# location_description
# longitude
# n_guns_involved
# notes
# participant_age
# participant_age_group
# participant_gender
# participant_name
# participant_relationship
# participant_status
# participant_type
# sources
# state_house_district
# state_senate_district

# %%
Inc_Frequencies = gvData.incident_characteristics.str.split('|', expand=True).stack().value_counts().reset_index()
Inc_Frequencies.columns = ['Inc Characteristic', 'Count']
Inc_Frequencies.to_csv(r'C:\Users\pcallahan\Desktop\school\580\gun-violence-data-master\rawdata', index=False)
# Out:
#                                     Inc Characteristic   Count
# 0                                                       337184
# 1                               Shot - Wounded/Injured   93926
# 2            Shot - Dead (murder, accidental, suicide)   53409
# 3                                Non-Shooting Incident   44837
# 4                            Shots Fired - No Injuries   35750
# ..                                                 ...     ...
# 105  Mistaken ID (thought it was an intruder/threat...      80
# 106       Officer Involved Shooting - Bystander killed      31
# 107                              Terrorism Involvement      30
# 108                                 Political Violence      13
# 109                                                NAV       2
#
# [110 rows x 2 columns]

# %%
#get list of states
states=[]
for state in gvData.state:
    if state not in states:
        states.append(state)

# %%
vaData = gvData.loc[gvData['state'] == 'Virginia']
Inc_Frequencies = vaData.incident_characteristics.str.split('|', expand=True).stack().value_counts().reset_index()
Inc_Frequencies.columns = ['Inc Characteristic', 'Count']
Inc_Frequencies.sort_values(by=['Inc Characteristic'])
# Out:
#                                     Inc Characteristic  Count
# 0                                                        6036
# 1                               Shot - Wounded/Injured   2908
# 2            Shot - Dead (murder, accidental, suicide)   1294
# 3                            Shots Fired - No Injuries    791
# 4                                Non-Shooting Incident    665
# ..                                                 ...    ...
# 100              Concealed Carry License - Perpetrator      1
# 101                                Gun buy back action      1
# 102       Officer Involved Shooting - Bystander killed      1
# 103  Spree Shooting (multiple victims, multiple loc...      1
# 104                              Terrorism Involvement      1
#
# [105 rows x 2 columns]

# %%
for state in states:
    stateData = gvData.loc[gvData['state'] == state]
    Inc_Frequencies = vaData.incident_characteristics.str.split('|', expand=True).stack().value_counts().reset_index()
    Inc_Frequencies.columns = ['Inc Characteristic', 'Count']
    Inc_Frequencies
